# %% [markdown]
# # C1 Program
# Develop a python program to store and display Employee details such as EID, Name, Place, and Department. The EID must be auto-generated for each employee.

# %%
class employee:
    count = 00
    def __init__(self,name,place,department):
        employee.count = employee.count + 1
        self.customerID = employee.count
        self.name = name
        self.place = place
        self.department = department
        
    def customerID(self):
        return self.customerID
        
    def customerdetails(self):
        print("\nCustomer Detials")
        print("\nCustomer ID : ",self.customerID,
              "\nCustomer name: ",self.name,
              "\nCustomer Place: ",self.place,
              "\nCustomer Department: ",self.department)
    def TotalCustomer(self):
        return employee.count
        
name = input("Enter your name: \n")
place = input("Enter Your Place: \n")
department = input("Enter Your Department: \n")

C1 = employee(name,place,department)
C1.customerdetails()

name = input("Enter your name: \n")
place = input("Enter Your Place: \n")
department = input("Enter Your Department: \n")

C2 = employee(name,place,department)
C2.customerdetails()
# Out:
# Enter your name:
#  Prashanth
# Enter Your Place:
#  Mysuru
# Enter Your Department:
#  ISE
# Customer Detials
#
# Customer ID :  1
# Customer name:  Prashanth
# Customer Place:  Mysuru
# Customer Department:  ISE
# Enter your name:
#  Preetham
# Enter Your Place:
#  Banglore
# Enter Your Department:
#  CSE
# Customer Detials
#
# Customer ID :  2
# Customer name:  Preetham
# Customer Place:  Banglore
# Customer Department:  CSE

# %% [markdown]
# # C2 Program
# Explore the automobile dataset and visualize the i) Distribution of the two and four door cars with respect to the type of fuel they use ii) Distribution of cars of different body styles with respect to the type of fuel they use ii) Total number of each type of body style cars categorized by fuel type iii) Horsepower of each of the fuel type with reference to the type of drive wheel present in cars. (https://www.kaggle.com/datasets/toramky/automobile-dataset?resource=download)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('Automobile_data.csv')
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
sns.countplot(x = 'num-of-doors',hue = 'fuel-type',data = df)
plt.title("Distribution of the two and four door cars w.r.t the type of fuel they use")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x = 'body-style',hue = 'fuel-type',data = df)
plt.title("Distribution of cars of different body styles with respect to the type of fuel they use")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x = 'body-style',hue = 'fuel-type',data = df)
plt.title("Total number of each type of body style cars categorized by fuel type")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.replace('?',np.nan,inplace=True)
df = df.explode('horsepower')
df['horsepower'] = df['horsepower'].astype(float)
sns.boxplot(data=df, x='fuel-type', y='horsepower', hue='drive-wheels')
plt.show()
